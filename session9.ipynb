# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
random1000=np.random.rand(1000)

# %%
print(random1000[13])
# Out:
# 0.7884177876777532

# %%
plt.hist(random1000,100,{0,1})
plt.ylabel("Numbers in bin")
plt.xlabel("Random Numbers")
plt.savefig("randomhistogram.pdf",bbox_inches="tight",facecolor="white")
