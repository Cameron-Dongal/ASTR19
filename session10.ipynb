# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.poisson(20,1000)

plt.hist(x,100,{0,40})
plt.ylabel("Numbers per bin")
plt.xlabel("Bin")
plt.savefig("poissonhistogram.pdf",bbox_inches="tight",facecolor="white")
